# %%
# python program to swap two cities

# To take inputs from the user 
city_1 =input('enter the name of city 1')
city_2 =input('enter the name of city 2')

# create a temporary variable and swap the cities 
temp = city_1 
city_1 = city_2
city_2 =temp

print(f"the name of city 1 after swapping is (city_1)")
print(f"the name of city 2 after swapping is (city_2)")
# Out:
# enter the name of city 1 london
# enter the name of city 2 ghana
# the name of city 1 after swapping is (city_1)
# the name of city 2 after swapping is (city_2)
